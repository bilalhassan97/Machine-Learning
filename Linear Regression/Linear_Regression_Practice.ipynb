# %%
import pandas as pd
import seaborn as sns

coronavirus_dataset=pd.read_csv('../Datasets/brazil_covid19.csv')

coronavirus_dataset.head()
# Out:
#          date        region state  cases  deaths
# 0  2020-02-25  Centro-Oeste    DF      0       0
# 1  2020-02-25  Centro-Oeste    GO      0       0
# 2  2020-02-25  Centro-Oeste    MS      0       0
# 3  2020-02-25  Centro-Oeste    MT      0       0
# 4  2020-02-25      Nordeste    AL      0       0

# %%
sns.relplot(x='cases',y='deaths',data=coronavirus_dataset,kind='line')

# %%
sns.regplot(x='cases',y='deaths',data=coronavirus_dataset)
# Out:
# <AxesSubplot:xlabel='cases', ylabel='deaths'>

# %%
import seaborn as sns

sns.heatmap(coronavirus_dataset.isnull(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
X=coronavirus_dataset['cases'].values
Y=coronavirus_dataset['deaths']
print(X)
# Out:
# [     0      0      0 ... 187729 207706 222652]

# %%
m = 0
c = 0

L = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
   
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    print(m)
    c = c - L * D_c  # Update c
    
print (m, c)
# Out:
# 110227.38825644052
# -336550250338.346
# 1.0275677387587951e+18
# -3.1374080294880765e+24
# 9.57925085832888e+30
# -2.9247724919530836e+37
# 8.93002412839802e+43
# -2.726548172658692e+50
# 8.324798265872182e+56
# -2.5417583618150742e+63
# 7.760591144102626e+69
# -2.3694925454249704e+76
# 7.234622747895998e+82
# -2.2089019189122245e+89
# 6.744301475558092e+95
# -2.0591952048108315e+102
# 6.287211369306474e+108
# -1.91963475390707e+115
# 5.861100211132765e+121
# -1.789532910623872e+128
# 5.463868425459023e+134
# -1.6682486247386358e+141
# 5.0935587339084654e+147
# -1.5551842927393318e+154
# 4.74834651121665e+160
# -1.449782813255461e+167
# 4.4265307947636844e+173
# -1.3515248420549865e+180
# 4.126525903428788e+186
# -1.2599262330818443e+193
# 3.8468536244709e+199
# -1.1745356529252943e+206
# 3.5861359299377844e+212
# -1.0949323569668342e+219
# 3.343088186715064e+225
# -1.0207241162471524e+232
# 3.1165128267593985e+238
# -9.515452848381692e+244
# 2.905293446326807e+251
# ...
